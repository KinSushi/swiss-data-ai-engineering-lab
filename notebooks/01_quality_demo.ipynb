# %% [markdown]
# # Quality demo notebook
# Notebook awareness only. Core logic lives in `src/python/quality_checks.py`.

# %%
from src.python.quality_checks import run_quality_checks
run_quality_checks()
